# %%
import numpy as np
from numpy import random
import pandas as pd
import math
import statistics as stats
import scipy
from scipy import stats
from scipy.stats import skew,spearmanr,kurtosis
import matplotlib.pyplot as plt
from array import *

# %%
df = pd.DataFrame(columns=['Tau','Rho','Phi',
                         'student1','student2','student3','student4','student5',
                         'student6','student7','student8','student9','student10',
                         'student11','student12','student13','student14','student15',
                         'student16','student17','student18','student19','student20',
                         'master1','master2','master3','master4','master5',
                         'master6','master7','master8','master9','master10',
                         'master11','master12','master13','master14','master15',
                         'master16','master17','master18','master19','master20',
                         'sSupra','sInfra','sbmForward','sbmBackward',
                         'empStudentbMaster','maxStudentbMaster','CorrStudentbMaster',
                         'mSupra','mInfra','mbsForward','mbsBackward',
                         'empMasterbStudent','maxMasterbStudent','CorrMasterbStudent' 
                        
                           ])

# %%
i=0
while i <=10000:

    value1=1                                 #continous numbers data as basis for ranks
    value2=2
    value3=3
    value4=random.randint(1,100000000)
    value5=random.randint(1,100000000)
    value6=random.randint(1,100000000)
    value7=random.randint(1,100000000)
    value8=random.randint(1,100000000)
    value9=random.randint(1,100000000)
    value10=random.randint(1,100000000)
    value11=random.randint(1,100000000)
    value12=random.randint(1,100000000)
    value13=random.randint(1,100000000)
    value14=random.randint(1,100000000)
    value15=random.randint(1,100000000)
    value16=random.randint(1,100000000)
    value17=random.randint(1,100000000)
    value18=random.randint(1,100000000)
    value19=random.randint(1,100000000)
    value20=random.randint(1,100000000)
    
    values=[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
            value11,value12,value13,value14,value15,value16,value17,value18,value19,value20]

    values_list = [[value1, 1], [value2, 2], [value3, 3],[value4, 4], [value5, 5],    #matching values
                  [value6, 6],[value7, 7], [value8, 8], [value9, 9],[value10, 10],
                  [value11, 11],[value12, 12],[value13, 13],[value14, 14],[value15, 15],
                  [value16, 16],[value17, 17],[value18, 18],[value19, 19],[value20, 20]]
    
    sorted_by_values = sorted(values_list, key=lambda x: x[0])
   
    master1=(sorted_by_values[0][1]) #reading ranks sorted according to continous values
    master2=(sorted_by_values[1][1])
    master3=(sorted_by_values[2][1])
    master4=(sorted_by_values[3][1])
    master5=(sorted_by_values[4][1])
    master6=(sorted_by_values[5][1])
    master7=(sorted_by_values[6][1])
    master8=(sorted_by_values[7][1])
    master9=(sorted_by_values[8][1])
    master10=(sorted_by_values[9][1])
    master11=(sorted_by_values[10][1])
    master12=(sorted_by_values[11][1])
    master13=(sorted_by_values[12][1])
    master14=(sorted_by_values[13][1])
    master15=(sorted_by_values[14][1])
    master16=(sorted_by_values[15][1])
    master17=(sorted_by_values[16][1])
    master18=(sorted_by_values[17][1])
    master19=(sorted_by_values[18][1])
    master20=(sorted_by_values[19][1])
   
    val1=1                                 #continous numbers data as basis for ranks
    val2=2
    val3=3
    val4=random.randint(1,100000000)
    val5=random.randint(1,100000000)
    val6=random.randint(1,100000000)
    val7=random.randint(1,100000000)
    val8=random.randint(1,100000000)
    val9=random.randint(1,100000000)
    val10=random.randint(1,100000000)
    val11=random.randint(1,100000000)
    val12=random.randint(1,100000000)
    val13=random.randint(1,100000000)
    val14=random.randint(1,100000000)
    val15=random.randint(1,100000000)
    val16=random.randint(1,100000000)
    val17=random.randint(1,100000000)
    val18=random.randint(1,100000000)
    val19=random.randint(1,100000000)
    val20=random.randint(1,100000000)
    
    vals=[val1,val2,val3,val4,val5,val6,val7,val8,val9,val10,
          val11,val12,val13,val14,val15,val16,val17,val18,val19,val20]

    vals_list = [[val1, 1], [val2, 2], [val3, 3],[val4, 4], [val5, 5], 
                 [val6, 6],[val7, 7], [val8, 8], [val9, 9],[val10, 10],
                 [val11, 11],[val12, 12],[val13, 13],[val14, 14],[val15, 15],
                 [val16, 16],[val17, 17],[val18, 18],[val19, 19],[val20, 20]]
    
    sorted_by_vals = sorted(vals_list, key=lambda x: x[0])
    
    student1=(sorted_by_vals[0][1])
    student2=(sorted_by_vals[1][1])
    student3=(sorted_by_vals[2][1])
    student4=(sorted_by_vals[3][1])
    student5=(sorted_by_vals[4][1])
    student6=(sorted_by_vals[5][1])
    student7=(sorted_by_vals[6][1])
    student8=(sorted_by_vals[7][1])
    student9=(sorted_by_vals[8][1])
    student10=(sorted_by_vals[9][1])
    student11=(sorted_by_vals[10][1])
    student12=(sorted_by_vals[11][1])
    student13=(sorted_by_vals[12][1])
    student14=(sorted_by_vals[13][1])
    student15=(sorted_by_vals[14][1])
    student16=(sorted_by_vals[15][1])
    student17=(sorted_by_vals[16][1])
    student18=(sorted_by_vals[17][1])
    student19=(sorted_by_vals[18][1])
    student20=(sorted_by_vals[19][1])
    
    
    master=[master1,master2,master3,master4,master5,master6,master7,master8,master9,master10,
            master11,master12,master13,master14,master15,master16,master17,master18,master19,master20]
    
    student=[student1,student2,student3,student4,student5,student6,student7,student8,student9,student10,
             student11,student12,student13,student14,student15,student16,student17,student18,student19,student20]
    
    summaster=(master1+master2+master3+master4+master5+master6+master7+master8+master9+master10+
               master11+master12,master13+master14+master15+master16+master17,master18+master19+master20)
    
    sumstudent=(student1+student2+student3+student4+student5+student6+student7+student8+student9+student10+
                student11+student12+student13+student14+student15+student16+student17+student18+student19+student20)
    
   
    Tau, piTau = stats.kendalltau(master,student)
    
    m1=master[0]
    m2=master[1]
    m3=master[2]
    m4=master[3]
    m5=master[4]
    m6=master[5]
    m7=master[6]
    m8=master[7]
    m9=master[8]
    m10=master[9]
    m11=master[10]
    m12=master[11]
    m13=master[12]
    m14=master[13]
    m15=master[14]
    m16=master[15]
    m17=master[16]
    m18=master[17]
    m19=master[18]
    m20=master[19]    
        
    s1=student[0]
    s2=student[1]
    s3=student[2]
    s4=student[3]
    s5=student[4]
    s6=student[5]
    s7=student[6]
    s8=student[7]
    s9=student[8]
    s10=student[9]
    s11=student[10]
    s12=student[11] 
    s13=student[12]
    s14=student[13]
    s15=student[14] 
    s16=student[15]
    s17=student[16] 
    s18=student[17]
    s19=student[18]
    s20=student[19] 
    
    Rho, piRho =stats.spearmanr([m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18,m19,m20],
                                [s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19,s20])
    
    multi_list = [[m1, s1], [m2, s2], [m3, s3],[m4, s4], [m5, s5], 
                  [m6, s6],[m7, s7], [m8, s8], [m9, s9],[m10, s10],
                  [m11, s11],[m12, s12],[m13, s13],[m14, s14],[m15, s15], 
                  [m16, s16],[m17, s17],[m18, s18],[m19, s19],[m20, s20]]

    
    sorted_by_student = sorted(multi_list, key=lambda x: x[1])
    sorted_by_master = sorted(multi_list, key=lambda x: x[0])
    
    ##########################################################################################
    #proportional difference to higher ranks
    
    #sorted by student
    s1=(sorted_by_student[0][1])
    s2=(sorted_by_student[1][1])
    s3=(sorted_by_student[2][1])
    s4=(sorted_by_student[3][1])
    s5=(sorted_by_student[4][1])
    s6=(sorted_by_student[5][1])
    s7=(sorted_by_student[6][1])
    s8=(sorted_by_student[7][1])
    s9=(sorted_by_student[8][1])
    s10=(sorted_by_student[9][1]) 
    s11=(sorted_by_student[10][1]) 
    s12=(sorted_by_student[11][1])
    s13=(sorted_by_student[12][1]) 
    s14=(sorted_by_student[13][1]) 
    s15=(sorted_by_student[14][1]) 
    s16=(sorted_by_student[15][1]) 
    s17=(sorted_by_student[16][1])
    s18=(sorted_by_student[17][1]) 
    s19=(sorted_by_student[18][1]) 
    s20=(sorted_by_student[19][1])
    
    
    aboves1=(s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves2=(s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves3=(s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves4=(s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves5=(s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves6=(s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves7=(s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves8=(s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20)
    aboves9=s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20
    aboves10=s11+s12+s13+s14+s15+s16+s17+s18+s19+s20
    aboves11=s12+s13+s14+s15+s16+s17+s18+s19+s20
    aboves12=s13+s14+s15+s16+s17+s18+s19+s20
    aboves13=s14+s15+s16+s17+s18+s19+s20
    aboves14=s15+s16+s17+s18+s19+s20
    aboves15=s16+s17+s18+s19+s20
    aboves16=s17+s18+s19+s20
    aboves17=s18+s19+s20
    aboves18=s19+s20
    aboves19=s20
   
    sSupra1=aboves1/s1
    sSupra2=aboves2/s2
    sSupra3=aboves3/s3
    sSupra4=aboves4/s4
    sSupra5=aboves5/s5
    sSupra6=aboves6/s6
    sSupra7=aboves7/s7
    sSupra8=aboves8/s8
    sSupra9=aboves9/s9
    sSupra10=aboves10/s10
    sSupra11=aboves11/s11
    sSupra12=aboves12/s12
    sSupra13=aboves13/s13
    sSupra14=aboves14/s14
    sSupra15=aboves15/s15
    sSupra16=aboves16/s16
    sSupra17=aboves17/s17
    sSupra18=aboves18/s18
    sSupra19=aboves19/s19

    sSupra=(sSupra1+sSupra2+sSupra3+sSupra4+sSupra5+sSupra6+sSupra7+sSupra8+sSupra9+sSupra10+
            sSupra11+sSupra12+sSupra13+sSupra14+sSupra15+sSupra16+sSupra17+sSupra18+sSupra19
           )-190

    
    
    ######################################################################
    #proportional difference to lower ranks
    
    belows20=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19)
    belows19=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18)
    belows18=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17)
    belows17=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16)
    belows16=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)
    belows15=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14)
    belows14=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13)
    belows13=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12)
    belows12=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11)
    belows11=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10)
    belows10=(s1+s2+s3+s4+s5+s6+s7+s8+s9)
    belows9=(s1+s2+s3+s4+s5+s6+s7+s8)
    belows8=(s1+s2+s3+s4+s5+s6+s7)
    belows7=(s1+s2+s3+s4+s5+s6)
    belows6=(s1+s2+s3+s4+s5)
    belows5=(s1+s2+s3+s4)
    belows4=(s1+s2+s3)
    belows3=(s1+s2)
    belows2=s1
    
    sInfra20=belows20/s20
    sInfra19=belows19/s19
    sInfra18=belows18/s18
    sInfra17=belows17/s17
    sInfra16=belows16/s16
    sInfra15=belows15/s15
    sInfra14=belows14/s14
    sInfra13=belows13/s13
    sInfra12=belows12/s12
    sInfra11=belows11/s11
    sInfra10=belows10/s10
    sInfra9=belows9/s9
    sInfra8=belows8/s8
    sInfra7=belows7/s7
    sInfra6=belows6/s6
    sInfra5=belows5/s5
    sInfra4=belows4/s4
    sInfra3=belows3/s3
    sInfra2=belows2/s2
    
    sInfra=190-(sInfra2+sInfra3+sInfra4+sInfra5+sInfra6+sInfra7+sInfra8+sInfra9+sInfra10+sInfra11+
    belowsbm10=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9)
    belowsbm9=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8)
    belowsbm8=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7)
    belowsbm7=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6)
    belowsbm6=(sbm1+sbm2+sbm3+sbm4+sbm5)
    belowsbm5=(sbm1+sbm2+sbm3+sbm4)
    belowsbm4=(sbm1+sbm2+sbm3)
    belowsbm3=(sbm1+sbm2)
    belowsbm2= sbm1
    
    sbmBackward20=belowsbm20/sbm20
    sbmBackward19=belowsbm19/sbm19
    sbmBackward18=belowsbm18/sbm18
    sbmBackward17=belowsbm17/sbm17
    sbmBackward16=belowsbm16/sbm16
    sbmBackward15=belowsbm15/sbm15
    sbmBackward14=belowsbm14/sbm14
    sbmBackward13=belowsbm13/sbm13
    sbmBackward12=belowsbm12/sbm12
    sbmBackward11=belowsbm11/sbm11
    sbmBackward10=belowsbm10/sbm10
    sbmBackward9=belowsbm9/sbm9
    sbmBackward8=belowsbm8/sbm8
    sbmBackward7=belowsbm7/sbm7
    sbmBackward6=belowsbm6/sbm6
    sbmBackward5=belowsbm5/sbm5
    sbmBackward4=belowsbm4/sbm4
    sbmBackward3=belowsbm3/sbm3
    sbmBackward2=belowsbm2/sbm2
    
    sbmBackward=190-(sbmBackward2+sbmBackward3+sbmBackward4+sbmBackward5+sbmBackward6+
                     sbmBackward7+sbmBackward8+sbmBackward9+sbmBackward10+sbmBackward11+
                     sbmBackward12+sbmBackward13+sbmBackward14+sbmBackward15+sbmBackward16+
                     sbmBackward17+sbmBackward18+sbmBackward19+sbmBackward20)
   
    ####################################################################################
    #Corrxy
    
    empStudentbMaster=(sbmForward+sbmBackward) 
    maxStudentbMaster=(sSupra+sInfra)
    CorrStudentbMaster=empStudentbMaster/maxStudentbMaster
   
    ######################################################################################
    #####################################################################################
  
    #master sorted by master
    m1=(sorted_by_master[0][0])
    m2=(sorted_by_master[1][0])
    m3=(sorted_by_master[2][0])
    m4=(sorted_by_master[3][0])
    m5=(sorted_by_master[4][0])
    m6=(sorted_by_master[5][0])
    m7=(sorted_by_master[6][0])
    m8=(sorted_by_master[7][0])
    m9=(sorted_by_master[8][0])
    m10=(sorted_by_master[9][0])
    m11=(sorted_by_master[10][0])
    m12=(sorted_by_master[11][0])
    m13=(sorted_by_master[12][0])
    m14=(sorted_by_master[13][0])
    m15=(sorted_by_master[14][0]) 
    m16=(sorted_by_master[15][0])
    m17=(sorted_by_master[16][0])
    m18=(sorted_by_master[17][0])
    m19=(sorted_by_master[18][0])
    m20=(sorted_by_master[19][0]) 
  
    
    #Max
   
    abovem1=(m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem2=(m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem3=(m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem4=(m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem5=(m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem6=(m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem7=(m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem8=(m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20)
    abovem9=m10+m11+m12+m13+m14+m15+m16+m17+m18+m19+m20
    abovem10=m11+m12+m13+m14+m15+m16+m17+m18+m19+m20
    abovem11=m12+m13+m14+m15+m16+m17+m18+m19+m20
    abovem12=m13+m14+m15+m16+m17+m18+m19+m20
    abovem13=m14+m15+m16+m17+m18+m19+m20
    abovem14=m15+m16+m17+m18+m19+m20
    abovem15=m16+m17+m18+m19+m20
    abovem16=m17+m18+m19+m20
    abovem17=m18+m19+m20
    abovem18=m19+m20
    abovem19=m20
   
    mSupra1=abovem1/m1
    mSupra2=abovem2/m2
    mSupra3=abovem3/m3
    mSupra4=abovem4/m4
    mSupra5=abovem5/m5
    mSupra6=abovem6/m6
    mSupra7=abovem7/m7
    mSupra8=abovem8/m8
    mSupra9=abovem9/m9
    mSupra10=abovem10/m10
    mSupra11=abovem11/m11
    mSupra12=abovem12/m12
    mSupra13=abovem13/m13
    mSupra14=abovem14/m14 
    mSupra15=abovem15/m15
    mSupra16=abovem16/m16
    mSupra17=abovem17/m17
    mSupra18=abovem18/m18
    mSupra19=abovem19/m19

    mSupra=(mSupra1+mSupra2+mSupra3+mSupra4+mSupra5+mSupra6+mSupra7+mSupra8+mSupra9+mSupra10+
            mSupra11+mSupra12+mSupra13+mSupra14+mSupra15+mSupra16+mSupra17+mSupra18+mSupra19)-190

    ######################################################################
    #Max below
    
    belowm20=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18+m19)
    belowm19=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17+m18)
    belowm18=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16+m17)
    belowm17=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15+m16)
    belowm16=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)
    belowm15=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14)
    belowm14=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13)
    belowm13=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12)
    belowm12=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11)
    belowm11=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10)
    belowm10=(m1+m2+m3+m4+m5+m6+m7+m8+m9)
    belowm9=(m1+m2+m3+m4+m5+m6+m7+m8)
    belowm8=(m1+m2+m3+m4+m5+m6+m7)
    belowm7=(m1+m2+m3+m4+m5+m6)
    belowm6=(m1+m2+m3+m4+m5)
    belowm5=(m1+m2+m3+m4)
    belowm4=(m1+m2+m3)
    belowm3=(m1+m2)
    belowm2=m1
    
    mInfra20=belowm20/m20
    mInfra19=belowm19/m19
    mInfra18=belowm18/m18
    mInfra17=belowm17/m17
    mInfra16=belowm16/m16
    mInfra15=belowm15/m15
    mInfra14=belowm14/m14
    mInfra13=belowm13/m13
    mInfra12=belowm12/m12
    mInfra11=belowm11/m11
    mInfra10=belowm10/m10
    mInfra9=belowm9/m9
    mInfra8=belowm8/m8
    mInfra7=belowm7/m7
    mInfra6=belowm6/m6
    mInfra5=belowm5/m5
    mInfra4=belowm4/m4
    mInfra3=belowm3/m3
    mInfra2=belowm2/m2
    
    mInfra=190-(mInfra2+mInfra3+mInfra4+mInfra5+mInfra6+mInfra7+mInfra8+mInfra9+mInfra10+
                mInfra11+mInfra12+mInfra13+mInfra14+mInfra15+mInfra16+mInfra17+mInfra18+mInfra19+mInfra20)
    

    ##################################################################################################
    #forward
   
    #master sorted by student
    mbs1=(sorted_by_student[0][0])
    mbs2=(sorted_by_student[1][0])
    mbs3=(sorted_by_student[2][0])
    mbs4=(sorted_by_student[3][0])
    mbs5=(sorted_by_student[4][0])
    mbs6=(sorted_by_student[5][0])
    mbs7=(sorted_by_student[6][0])
    mbs8=(sorted_by_student[7][0])
    mbs9=(sorted_by_student[8][0])
    mbs10=(sorted_by_student[9][0])
    mbs11=(sorted_by_student[10][0])
    mbs12=(sorted_by_student[11][0])
    mbs13=(sorted_by_student[12][0])
    mbs14=(sorted_by_student[13][0])
    mbs15=(sorted_by_student[14][0])
    mbs16=(sorted_by_student[15][0])
    mbs17=(sorted_by_student[16][0])
    mbs18=(sorted_by_student[17][0])
    mbs19=(sorted_by_student[18][0])
    mbs20=(sorted_by_student[19][0])

    abovembs1=(mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16+mbs17+mbs18+mbs19+mbs20)
    abovembs2=(mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16+mbs17+mbs18+mbs19+mbs20)
    abovembs3=(mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16+mbs17+mbs18+mbs19+mbs20)
    abovembs4=(mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16+mbs17+mbs18+mbs19+mbs20)
    belowmbs18=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16+mbs17)
    belowmbs17=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15+mbs16)
    belowmbs16=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)
    belowmbs15=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14)
    belowmbs14=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13)
    belowmbs13=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12)
    belowmbs12=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11)
    belowmbs11=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10)
    belowmbs10=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9)
    belowmbs9=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8)
    belowmbs8=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7)
    belowmbs7=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6)
    belowmbs6=(mbs1+mbs2+mbs3+mbs4+mbs5)
    belowmbs5=(mbs1+mbs2+mbs3+mbs4)
    belowmbs4=(mbs1+mbs2+mbs3)
    belowmbs3=(mbs1+mbs2)
    belowmbs2= mbs1
    
    mbsBackward20=belowmbs20/mbs20
    mbsBackward19=belowmbs19/mbs19
    mbsBackward18=belowmbs18/mbs18
    mbsBackward17=belowmbs17/mbs17
    mbsBackward16=belowmbs16/mbs16
    mbsBackward15=belowmbs15/mbs15
    mbsBackward14=belowmbs14/mbs14
    mbsBackward13=belowmbs13/mbs13
    mbsBackward12=belowmbs12/mbs12
    mbsBackward11=belowmbs11/mbs11
    mbsBackward10=belowmbs10/mbs10
    mbsBackward9=belowmbs9/mbs9
    mbsBackward8=belowmbs8/mbs8
    mbsBackward7=belowmbs7/mbs7
    mbsBackward6=belowmbs6/mbs6
    mbsBackward5=belowmbs5/mbs5
    mbsBackward4=belowmbs4/mbs4
    mbsBackward3=belowmbs3/mbs3
    mbsBackward2=belowmbs2/mbs2
    
    mbsBackward=190-(mbsBackward2+mbsBackward3+mbsBackward4+mbsBackward5+
                     mbsBackward6+mbsBackward7+mbsBackward8+mbsBackward9+
                     mbsBackward10+mbsBackward11+mbsBackward12+mbsBackward13+
                     mbsBackward14+mbsBackward15+mbsBackward16+mbsBackward17+
                     mbsBackward18+mbsBackward19+mbsBackward20)
   
    ####################################################################################
    #Corryx
    empMasterbStudent=(mbsForward+mbsBackward) 
    maxMasterbStudent=(mSupra+mInfra)
    CorrMasterbStudent=empMasterbStudent/maxMasterbStudent
    
    Phi=(CorrStudentbMaster+CorrMasterbStudent)/2
   
    #######################################################
    
    master1=m1
    master2=m2
    master3=m3
    master4=m4
    master5=m5
    master6=m6
    master7=m7
    master8=m8
    master9=m9
    master10=m10
    master11=m11
    master12=m12
    master13=m13
    master14=m14
    master15=m15
    master16=m16
    master17=m17
    master18=m18
    master19=m19
    master20=m20
    
    student1=sbm1
    student2=sbm2
    student3=sbm3
    student4=sbm4
    student5=sbm5
    student6=sbm6
    student7=sbm7
    student8=sbm8
    student9=sbm9
    student10=sbm10
    student11=sbm11
    student12=sbm12
    student13=sbm13
    student14=sbm14
    student15=sbm15
    student16=sbm16
    student17=sbm17
    student18=sbm18
    student19=sbm19
    student20=sbm20
    
    ############################################################################################## 
    i+=1
    
    df.loc[len(df)] = (Tau,Rho,Phi,
                        student1,student2,student3,student4,student5,
                         student6,student7,student8,student9,student10,
                         student11,student12,student13,student14,student15,
                         student16,student17,student18,student19,student20,
                         master1,master2,master3,master4,master5,
                         master6,master7,master8,master9,master10,
                         master11,master12,master13,master14,master15,
                         master16,master17,master18,master19,master20,
                         sSupra,sInfra,sbmForward,sbmBackward,
                         empStudentbMaster,maxStudentbMaster,CorrStudentbMaster,
                         mSupra,mInfra,mbsForward,mbsBackward,
                         empMasterbStudent,maxMasterbStudent,CorrMasterbStudent 
                         
                         
                        )

# %%
df
# Out:
#             Tau       Rho       Phi  student1  student2  student3  student4  \
# 0      0.294737  0.395489  0.669001       1.0       2.0       3.0      13.0
# 1      0.368421  0.511278  0.742736       1.0       2.0       3.0       8.0
# 2      0.094737  0.153383  0.536324       1.0       2.0       3.0      15.0
# 3      0.336842  0.433083  0.727344       1.0       2.0       3.0       4.0
# 4      0.294737  0.427068  0.702452       1.0       2.0       3.0      11.0
# ...         ...       ...       ...       ...       ...       ...       ...
# 9996   0.168421  0.257143  0.611112       1.0       2.0       3.0      14.0
# 9997   0.336842  0.460150  0.724346       1.0       2.0       3.0       8.0
# 9998   0.378947  0.472180  0.703024       1.0       2.0       3.0       9.0
# 9999   0.347368  0.511278  0.715643       1.0       2.0       3.0      17.0
# 10000  0.368421  0.487218  0.714365       1.0       2.0       3.0       9.0
#
# ...

# %%
#df.to_excel(r'C:/Documents/.../N20_Phi_3TopRanksConcordant.xlsx', sheet_name='Sheet1', index = True)

# %%
area = np.pi*4
plt.scatter(master,student, s = area, color='navy', alpha=1)
plt.title('Scatter plot')
plt.xlabel('master')
plt.ylabel('student')
plt.show()

# %%
Phi
# Out:
# 0.714365082430179

# %%
Rho
# Out:
# 0.4872180451127819

# %%
Tau
# Out:
# 0.3684210526315789

# %%
plt.hist(df['Phi'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of Phi')
plt.xlabel('Phi')
plt.ylabel('Dichte')
plt.show()
phi=df['Phi']
print('\nSkewness for data : ', skew(phi))
print('\nKurtosis for data : ', kurtosis(phi)) 
print('\nMean for data : ', np.mean(phi)) 
print('\nMedian for data : ', np.median(phi)) 
print('\nMin for data : ', min(phi)) 
print('\nMax for data : ', max(phi)) 
print('\nVar for data : ', np.var(phi)) 
print('\nStandard deviation for data : ', np.std(phi))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(phi,[50,95,99]))
# Out:
# Skewness for data :  0.04348824844042915
#
# Kurtosis for data :  -0.3614068711002054
#
# Mean for data :  0.674948513775481
#
# Median for data :  0.6738804362750548
#
# Min for data :  0.4055944684904369
#
# Max for data :  0.9511356870844602
#
# Var for data :  0.0074415168229433155
#
# Standard deviation for data :  0.08626422678575005
#
# Percentiles left25,righ95,right99 for data :  [0.67388044 0.81846898 0.86821471]

# %%
plt.hist(df['Tau'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of Tau')
plt.xlabel('Tau')
plt.ylabel('Dichte')
plt.show()
tau=df['Tau']
print('\nSkewness for data : ', skew(tau))
print('\nKurtosis for data : ', kurtosis(tau)) 
print('\nMean for data : ', np.mean(tau)) 
print('\nMedian for data : ', np.median(tau)) 
print('\nMin for data : ', min(tau)) 
print('\nMax for data : ', max(tau)) 
print('\nVar for data : ', np.var(tau)) 
print('\nStandard deviation for data : ', np.std(tau))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(tau,[50,95,99]))
# Out:
# Skewness for data :  0.021523980147640794
#
# Kurtosis for data :  -0.1799720636524791
#
# Mean for data :  0.28333587693861256
#
# Median for data :  0.28421052631578947
#
# Min for data :  -0.17894736842105263
#
# Max for data :  0.7473684210526316
#
# Var for data :  0.016441989604972014
#
# Standard deviation for data :  0.12822632181019628
#
# Percentiles left25,righ95,right99 for data :  [0.28421053 0.49473684 0.57894737]

# %%
plt.hist(df['Rho'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of Rho')
plt.xlabel('Rho')
plt.ylabel('Dichte')
plt.show()
rho=df['Rho']
print('\nSkewness for data : ', skew(rho))
print('\nKurtosis for data : ', kurtosis(rho)) 
print('\nMean for data : ', np.mean(rho)) 
print('\nMedian for data : ', np.median(rho)) 
print('\nMin for data : ', min(rho)) 
print('\nMax for data : ', max(rho)) 
print('\nVar for data : ', np.var(rho)) 
print('\nStandard deviation for data : ', np.std(rho))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(rho,[50,95,99]))
# Out:
# Skewness for data :  0.03303262421235896
#
# Kurtosis for data :  -0.30846719628142827
#
# Mean for data :  0.3857576648350216
#
# Median for data :  0.38496240601503756
#
# Min for data :  -0.11428571428571428
#
# Max for data :  0.8947368421052632
#
# Var for data :  0.023688273702474845
#
# Standard deviation for data :  0.15390995322744674
#
# Percentiles left25,righ95,right99 for data :  [0.38496241 0.6406015  0.73383459]
