# %%
import numpy as np
from numpy import random
import pandas as pd
import openpyxl
import os
import urllib
import math
import statistics as stats
import scipy
from scipy import stats
from scipy.stats import skew,spearmanr,kurtosis
import matplotlib.pyplot as plt
from array import *

# %%
df = pd.DataFrame(columns=['Phi','CorCoeff',
                           'master1','master2','master3','master4','master5',
                           'master6','master7','master8','master9','master10',
                           'master11','master12','master13','master14','master15',
                           'student1','student2','student3','student4','student5',
                           'student6','student7','student8','student9','student10',
                           'student11','student12','student13','student14','student15',
                           'sbm1','sbm2','sbm3','sbm4','sbm5',
                           'sbm6','sbm7','sbm8','sbm9','sbm10',
                           'sbm11','sbm12','sbm13','sbm14','sbm15',
                           'mbs1','mbs2','mbs3','mbs4','mbs5',
                           'mbs6','mbs7','mbs8','mbs9','mbs10',
                           'mbs11','mbs12','mbs13','mbs14','mbs15',
                           'F_sbm','B_sbm','Fr_s','Br_s','F_mbs','B_mbs','Fr_m','Br_m',
                           'CorStudentByMaster','CorMasterByStudent'
                           ])

# %%
i=0
while i <=12000:
   
    master1=random.randint(50,100)
    master2=random.randint(50,100)
    master3=random.randint(50,100)
    master4=random.randint(50,100)
    master5=random.randint(50,100)
    master6=random.randint(50,100)
    master7=random.randint(50,100)
    master8=random.randint(50,100)
    master9=random.randint(50,100)
    master10=random.randint(50,100)
    master11=random.randint(50,100)
    master12=random.choice([random.randint(1,10),random.randint(400,2000)])
    master13=random.randint(50,100)
    master14=random.randint(50,100)
    master15=random.randint(50,100)
                                     
    student1=random.randint(50,100)
    student2=random.randint(50,100)
    student3=random.randint(50,100)
    student4=random.randint(50,100)
    student5=random.randint(50,100)
    student6=random.randint(50,100)
    student7=random.randint(50,100)
    student8=random.randint(50,100)
    student9=random.randint(50,100)
    student10=random.randint(50,100)
    student11=random.randint(50,100)
    student12=random.randint(50,100)
    student13=random.randint(50,100)
    student14=random.randint(50,100)
    student15=random.randint(50,100)
    
    master=[master1,master2,master3,master4,master5,
            master6,master7,master8,master9,master10,
            master11,master12,master13,master14,master15]
    
    student=[student1,student2,student3,student4,student5,
             student6,student7,student8,student9,student10,
             student11,student12,student13,student14,student15]

    Covariance = np.cov(master, student)[0][1]
    CorCoeff=np.corrcoef(master,student)[0,1]
  
    m1=master[0]
    m2=master[1]
    m3=master[2]
    m4=master[3]
    m5=master[4]
    m6=master[5]
    m7=master[6]
    m8=master[7]
    m9=master[8]
    m10=master[9]
    m11=master[10]
    m12=master[11]
    m13=master[12]
    m14=master[13]
    m15=master[14]
   
    s1=student[0]
    s2=student[1]
    s3=student[2]
    s4=student[3]
    s5=student[4]
    s6=student[5]
    s7=student[6]
    s8=student[7]
    s9=student[8]
    s10=student[9]
    s11=student[10]
    s12=student[11]
    s13=student[12]
    s14=student[13]
    s15=student[14]
 
    multi_list = [[m1, s1], [m2, s2], [m3, s3],[m4, s4], [m5, s5], 
                  [m6, s6],[m7, s7], [m8, s8], [m9, s9],[m10, s10],
                  [m11, s11],[m12, s12],[m13, s13],[m14, s14],[m15, s15]]
    
    sorted_by_student = sorted(multi_list, key=lambda x: x[1])
    sorted_by_master = sorted(multi_list, key=lambda x: x[0])
    
   
    ##################################################################################################
    #F
   
    #student sorted by master
    sbm1=(sorted_by_master[0][1])
    sbm2=(sorted_by_master[1][1])
    sbm3=(sorted_by_master[2][1])
    sbm4=(sorted_by_master[3][1])
    sbm5=(sorted_by_master[4][1])
    sbm6=(sorted_by_master[5][1])
    sbm7=(sorted_by_master[6][1])
    sbm8=(sorted_by_master[7][1])
    sbm9=(sorted_by_master[8][1])
    sbm10=(sorted_by_master[9][1]) 
    sbm11=(sorted_by_master[10][1]) 
    sbm12=(sorted_by_master[11][1]) 
    sbm13=(sorted_by_master[12][1]) 
    sbm14=(sorted_by_master[13][1]) 
    sbm15=(sorted_by_master[14][1]) 
    
    sbmForward1=(sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm1
    sbmForward2=(sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm2
    sbmForward3=(sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm3
    sbmForward4=(sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm4
    sbmForward5=(sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm5
    sbmForward6=(sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm6
    sbmForward7=(sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm7
    sbmForward8=(sbm9+sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm8
    sbmForward9=(sbm10+sbm11+sbm12+sbm13+sbm14+sbm15)/sbm9
    sbmForward10=(sbm11+sbm12+sbm13+sbm14+sbm15)/sbm10
    sbmForward11=(sbm12+sbm13+sbm14+sbm15)/sbm11
    sbmForward12=(sbm13+sbm14+sbm15)/sbm12
    sbmForward13=(sbm14+sbm15)/sbm13
    sbmForward14=sbm15/sbm14
  
    F_sbm=(sbmForward1+sbmForward2+sbmForward3+sbmForward4+sbmForward5+sbmForward6+sbmForward7+
           sbmForward8+sbmForward9+sbmForward10+sbmForward11+sbmForward12+sbmForward13+sbmForward14)-105
    
    ######################################################################
    #B
    
    sbmBackward15=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13+sbm14)/sbm15
    sbmBackward14=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12+sbm13)/sbm14
    sbmBackward13=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11+sbm12)/sbm13
    sbmBackward12=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10+sbm11)/sbm12
    sbmBackward11=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9+sbm10)/sbm11
    sbmBackward10=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8+sbm9)/sbm10
    sbmBackward9=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7+sbm8)/sbm9
    sbmBackward8=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6+sbm7)/sbm8
    sbmBackward7=(sbm1+sbm2+sbm3+sbm4+sbm5+sbm6)/sbm7
    sbmBackward6=(sbm1+sbm2+sbm3+sbm4+sbm5)/sbm6
    sbmBackward5=(sbm1+sbm2+sbm3+sbm4)/sbm5
    sbmBackward4=(sbm1+sbm2+sbm3)/sbm4
    sbmBackward3=(sbm1+sbm2)/sbm3
    sbmBackward2= sbm1/sbm2
    
    B_sbm=105-(sbmBackward2+sbmBackward3+sbmBackward4+sbmBackward5+sbmBackward6+sbmBackward7+sbmBackward8+
               sbmBackward9+sbmBackward10+sbmBackward11+sbmBackward12+sbmBackward13+sbmBackward14+sbmBackward15)
    
    ##########################################################################################
    #F_r 
    
    s1=(sorted_by_student[0][1])
    s2=(sorted_by_student[1][1])
    s3=(sorted_by_student[2][1])
    s4=(sorted_by_student[3][1])
    s5=(sorted_by_student[4][1])
    s6=(sorted_by_student[5][1])
    s7=(sorted_by_student[6][1])
    s8=(sorted_by_student[7][1])
    s9=(sorted_by_student[8][1])
    s10=(sorted_by_student[9][1]) 
    s11=(sorted_by_student[10][1]) 
    s12=(sorted_by_student[11][1])
    s13=(sorted_by_student[12][1]) 
    s14=(sorted_by_student[13][1]) 
    s15=(sorted_by_student[14][1]) 
    
    
    Fr1=(s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)/s1
    Fr2=(s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)/s2
    Fr3=(s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)/s3
    Fr4=(s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)/s4
    Fr5=(s6+s7+s8+s9+s10+s11+s12+s13+s14+s15)/s5
    Fr6=(s7+s8+s9+s10+s11+s12+s13+s14+s15)/s6
    Fr7=(s8+s9+s10+s11+s12+s13+s14+s15)/s7
    Fr8=(s9+s10+s11+s12+s13+s14+s15)/s8
    Fr9=(s10+s11+s12+s13+s14+s15)/s9
    Fr10=(s11+s12+s13+s14+s15)/s10
    Fr11=(s12+s13+s14+s15)/s11
    Fr12=(s13+s14+s15)/s12
    Fr13=(s14+s15)/s13
    Fr14=s15/s14
   
    Fr_s=(Fr1+Fr2+Fr3+Fr4+Fr5+Fr6+Fr7+Fr8+Fr9+Fr10+Fr11+Fr12+Fr13+Fr14)-105

    ######################################################################
    #B_r
    
    Br15=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14)/s15
    Br14=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13)/s14
    Br13=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12)/s13
    Br12=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11)/s12
    Br11=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10)/s11
    Br10=(s1+s2+s3+s4+s5+s6+s7+s8+s9)/s10
    Br9=(s1+s2+s3+s4+s5+s6+s7+s8)/s9
    Br8=(s1+s2+s3+s4+s5+s6+s7)/s8
    Br7=(s1+s2+s3+s4+s5+s6)/s7
    Br6=(s1+s2+s3+s4+s5)/s6
    Br5=(s1+s2+s3+s4)/s5
    Br4=(s1+s2+s3)/s4
    Br3=(s1+s2)/s3
    Br2=s1/s2
   
    Br_s=105-(Br2+Br3+Br4+Br5+Br6+Br7+Br8+Br9+Br10+Br11+Br12+Br13+Br14+Br15)

    ##################################################################################################
    ##################################################################################################
  
    #master sorted by student
    mbs1=(sorted_by_student[0][0])
    mbs2=(sorted_by_student[1][0])
    mbs3=(sorted_by_student[2][0])
    mbs4=(sorted_by_student[3][0])
    mbs5=(sorted_by_student[4][0])
    mbs6=(sorted_by_student[5][0])
    mbs7=(sorted_by_student[6][0])
    mbs8=(sorted_by_student[7][0])
    mbs9=(sorted_by_student[8][0])
    mbs10=(sorted_by_student[9][0])
    mbs11=(sorted_by_student[10][0])
    mbs12=(sorted_by_student[11][0])
    mbs13=(sorted_by_student[12][0])
    mbs14=(sorted_by_student[13][0])
    mbs15=(sorted_by_student[14][0])

    mbsForward1=(mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs1
    mbsForward2=(mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs2
    mbsForward3=(mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs3
    mbsForward4=(mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs4
    mbsForward5=(mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs5
    mbsForward6=(mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs6
    mbsForward7=(mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs7
    mbsForward8=(mbs9+mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs8
    mbsForward9=(mbs10+mbs11+mbs12+mbs13+mbs14+mbs15)/mbs9
    mbsForward10=(mbs11+mbs12+mbs13+mbs14+mbs15)/mbs10
    mbsForward11=(mbs12+mbs13+mbs14+mbs15)/mbs11
    mbsForward12=(mbs13+mbs14+mbs15)/mbs12
    mbsForward13=(mbs14+mbs15)/mbs13
    mbsForward14=(mbs15)/mbs14
   
    F_mbs=(mbsForward1+mbsForward2+mbsForward3+mbsForward4+mbsForward5+mbsForward6+mbsForward7+mbsForward8+
           mbsForward9+mbsForward10+mbsForward11+mbsForward12+mbsForward13+mbsForward14)-105

    ######################################################################
    #B
    
    mbsBackward15=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13+mbs14)/mbs15
    mbsBackward14=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12+mbs13)/mbs14
    mbsBackward13=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11+mbs12)/mbs13
    mbsBackward12=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10+mbs11)/mbs12
    mbsBackward11=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9+mbs10)/mbs11
    mbsBackward10=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8+mbs9)/mbs10
    mbsBackward9=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7+mbs8)/mbs9
    mbsBackward8=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6+mbs7)/mbs8
    mbsBackward7=(mbs1+mbs2+mbs3+mbs4+mbs5+mbs6)/mbs7
    mbsBackward6=(mbs1+mbs2+mbs3+mbs4+mbs5)/mbs6
    mbsBackward5=(mbs1+mbs2+mbs3+mbs4)/mbs5
    mbsBackward4=(mbs1+mbs2+mbs3)/mbs4
    mbsBackward3=(mbs1+mbs2)/mbs3
    mbsBackward2= mbs1/mbs2
    
    B_mbs=105-(mbsBackward2+mbsBackward3+mbsBackward4+mbsBackward5+mbsBackward6+mbsBackward7+mbsBackward8+
               mbsBackward9+mbsBackward10+mbsBackward11+mbsBackward12+mbsBackward13+mbsBackward14+mbsBackward15)
    
    ######################################################################
    #F_r
    
    m1=(sorted_by_master[0][0])
    m2=(sorted_by_master[1][0])
    m3=(sorted_by_master[2][0])
    m4=(sorted_by_master[3][0])
    m5=(sorted_by_master[4][0])
    m6=(sorted_by_master[5][0])
    m7=(sorted_by_master[6][0])
    m8=(sorted_by_master[7][0])
    m9=(sorted_by_master[8][0])
    m10=(sorted_by_master[9][0])
    m11=(sorted_by_master[10][0])
    m12=(sorted_by_master[11][0])
    m13=(sorted_by_master[12][0])
    m14=(sorted_by_master[13][0])
    m15=(sorted_by_master[14][0]) 
  
    mForward1=(m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)/m1
    mForward2=(m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)/m2
    mForward3=(m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)/m3
    mForward4=(m5+m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)/m4
    mForward5=(m6+m7+m8+m9+m10+m11+m12+m13+m14+m15)/m5
    mForward6=(m7+m8+m9+m10+m11+m12+m13+m14+m15)/m6
    mForward7=(m8+m9+m10+m11+m12+m13+m14+m15)/m7
    mForward8=(m9+m10+m11+m12+m13+m14+m15)/m8
    mForward9=(m10+m11+m12+m13+m14+m15)/m9
    mForward10=(m11+m12+m13+m14+m15)/m10
    mForward11=(m12+m13+m14+m15)/m11
    mForward12=(m13+m14+m15)/m12
    mForward13=(m14+m15)/m13
    mForward14=m15/m14

    Fr_m=(mForward1+mForward2+mForward3+mForward4+mForward5+mForward6+mForward7+mForward8+
          mForward9+mForward10+mForward11+mForward12+mForward13+mForward14)-105

    ######################################################################
    #B_r
    
    mBackward15=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14)/m15
    mBackward14=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13)/m14
    mBackward13=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12)/m13
    mBackward12=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11)/m12
    mBackward11=(m1+m2+m3+m4+m5+m6+m7+m8+m9+m10)/m11
    mBackward10=(m1+m2+m3+m4+m5+m6+m7+m8+m9)/m10
    mBackward9=(m1+m2+m3+m4+m5+m6+m7+m8)/m9
    mBackward8=(m1+m2+m3+m4+m5+m6+m7)/m8
    mBackward7=(m1+m2+m3+m4+m5+m6)/m7
    mBackward6=(m1+m2+m3+m4+m5)/m6
    mBackward5=(m1+m2+m3+m4)/m5
    mBackward4=(m1+m2+m3)/m4
    mBackward3=(m1+m2)/m3
    mBackward2=m1/m2
    
   
    Br_m=105-(mBackward2+mBackward3+mBackward4+mBackward5+mBackward6+mBackward7+mBackward8+
              mBackward9+mBackward10+mBackward11+mBackward12+mBackward13+mBackward14+mBackward15)
    
    ####################################################################################
   
    CorStudentByMaster=(F_sbm+B_sbm)/(Fr_s+Br_s)
    CorMasterByStudent=(F_mbs+B_mbs)/(Fr_m+Br_m)
    Phi=(CorStudentByMaster+CorMasterByStudent)/2
    
    ######################################################################################
    i+=1
    
    df.loc[len(df)] = (Phi,CorCoeff,
                       master1,master2,master3,master4,master5,
                       master6,master7,master8,master9,master10,
                       master11,master12,master13,master14,master15,
                       student1,student2,student3,student4,student5,
                       student6,student7,student8,student9,student10,
                       student11,student12,student13,student14,student15,
                       sbm1,sbm2,sbm3,sbm4,sbm5,
                       sbm6,sbm7,sbm8,sbm9,sbm10,
                       sbm11,sbm12,sbm13,sbm14,sbm15,
                       mbs1,mbs2,mbs3,mbs4,mbs5,
                       mbs6,mbs7,mbs8,mbs9,mbs10,
                       mbs11,mbs12,mbs13,mbs14,mbs15,
                       F_sbm,B_sbm,Fr_s,Br_s,F_mbs,B_mbs,Fr_m,Br_m,
                       CorStudentByMaster,CorMasterByStudent
                       )

# %%
df
# Out:
#             Phi  CorCoeff  master1  master2  master3  master4  master5  \
# 0     -0.352879 -0.326845     86.0     54.0     74.0     66.0     52.0
# 1      0.522861  0.285047     72.0     83.0     82.0     78.0     53.0
# 2     -0.095746 -0.031666     52.0     53.0     83.0     64.0     74.0
# 3     -0.562812 -0.336304     81.0     83.0     88.0     75.0     65.0
# 4      0.461794  0.362575     64.0     55.0     55.0     78.0     97.0
# ...         ...       ...      ...      ...      ...      ...      ...
# 11996  0.525212  0.365319     72.0     60.0     57.0     65.0     50.0
# 11997  0.033271  0.084137     80.0     89.0     57.0     75.0     73.0
# 11998 -0.662593 -0.403832     89.0     77.0     72.0     54.0     91.0
# 11999  0.041004  0.176249     93.0     98.0     68.0     75.0     89.0
# 12000  0.454998  0.349147     90.0     94.0     56.0     95.0     98.0
#
#        master6  master7  master8  ...      F_sbm      B_sbm       Fr_s  \
# ...

# %%
df.to_excel(r'C:/Dokumente/Pandas2Excel/Q15_Phi_Outliers.xlsx', sheet_name='Tabel1', index = True)

# %%
area = np.pi*4

# Plot
plt.scatter(master, student, s = area, color='navy', alpha=1)
plt.title('Scatter plot')
plt.xlabel('master')
plt.ylabel('student')
plt.show()

# %%
CorCoeff
# Out:
# 0.34914710678237115

# %%
Phi
# Out:
# 0.45499835347052053
